# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras.layers as L
from tensorflow.keras import Model
from sklearn.metrics import f1_score
from tensorflow.keras import callbacks
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# # Load and process data

# %%
train = pd.read_csv("../input/liverpool-ion-switching/train.csv")
test = pd.read_csv("../input/liverpool-ion-switching/test.csv")
sub = pd.read_csv("../input/liverpool-ion-switching/sample_submission.csv", dtype=dict(time=str))

# %%
n_classes = train.open_channels.unique().shape[0]

# %%
seq_len = 1000

X = train.signal.values.reshape(-1, seq_len, 1)
y = train.open_channels.values.reshape(-1, seq_len, 1)

X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.2)

X_test = test.signal.values.reshape(-1, seq_len, 1)

# %% [markdown]
# # Modelling

# %%
def build_model(n_classes, seq_ln = 500, n_units = 256, learning_rate = 0.007):
    inputs = L.Input(shape = (seq_len, 1))
    x = L.Dense(n_units, activation = 'linear')(inputs)
    
    x = L.Bidirectional(L.LSTM(n_units, return_sequences = True))(x)
#     x = L.Dense(n_units, activation = 'relu')(x)
    x = L.Bidirectional(L.LSTM(n_units, return_sequences = True))(x)
#     x = L.Dense(n_units, activation = 'relu')(x)
    x = L.Bidirectional(L.LSTM(n_units, return_sequences = True))(x)
    x = L.Dense(n_units, activation = 'relu')(x)
#     x = L.Bidirectional(L.LSTM(n_units, return_sequences = True))(x)
#     x = L.Dense(n_units, activation = 'relu')(x)
#     x = L.Bidirectional(L.LSTM(n_units, return_sequences = True))(x)
    
#     x = L.Dense(n_units, activation = 'relu')(x)
    x = L.Dense(n_units, activation = 'relu')(x)
    x = L.Dense(n_classes, activation = 'softmax')(x)
    
    model = Model(inputs = inputs, outputs = x)
    model.compile(optimizer=Adam(lr=learning_rate), loss = 'sparse_categorical_crossentropy')
    
    return model
   
# learning_rate = 0.007
def lrs(epoch, learning_rate = 0.007):
    if epoch < 50:
        lr = learning_rate
    elif epoch < 100:
        lr = learning_rate/10
    else:
        lr = learning_rate/100
        
    return lr

# %%
model = build_model(n_classes, seq_len, learning_rate = 0.007)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 1000, 1)]         0
# _________________________________________________________________
# dense (Dense)                (None, 1000, 256)         512
# _________________________________________________________________
# bidirectional (Bidirectional (None, 1000, 512)         1050624
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 1000, 512)         1574912
# _________________________________________________________________
# bidirectional_2 (Bidirection (None, 1000, 512)         1574912
# _________________________________________________________________
# dense_1 (Dense)              (None, 1000, 256)         131328
# _________________________________________________________________
# dense_2 (Dense)              (None, 1000, 256)         65792
# _________________________________________________________________
# dense_3 (Dense)              (None, 1000, 11)          2827
# =================================================================
# Total params: 4,400,907
# Trainable params: 4,400,907
# Non-trainable params: 0
# _________________________________________________________________

# %%
class F1Callback(callbacks.Callback):
    def __init__(self, X_val, y_val):
        super().__init__()
        self.X = X_val
        self.y = y_val.reshape(-1)
    def on_epoch_begin(self, epoch, logs=None):
        if epoch == 0:
            return
        pred = (
            model
            .predict(self.X, batch_size=64)
            .argmax(axis=-1)
            .reshape(-1)
        )
        
        score = f1_score(self.y, pred, average='macro')
        
        print(f"val_f1_macro: {score:.4f}")

# %%
lr_schedule = callbacks.LearningRateScheduler(lrs)

model.fit(
    X_train, y_train, 
    batch_size=64,
    epochs=200,
    callbacks=[
        callbacks.ReduceLROnPlateau(),
        F1Callback(X_valid, y_valid),
        callbacks.ModelCheckpoint('model.h5'),
        lr_schedule
    ],
    validation_data=(X_valid, y_valid)
)
# Out:
# Train on 4000 samples, validate on 1000 samples
# Epoch 1/200
# 4000/4000 [==============================] - 58s 15ms/sample - loss: 1.5710 - val_loss: 1.2838
# val_f1_macro: 0.2972
# Epoch 2/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 1.2078 - val_loss: 1.0302
# val_f1_macro: 0.4092
# Epoch 3/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 1.0418 - val_loss: 0.8791
# val_f1_macro: 0.4640
# Epoch 4/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.8246 - val_loss: 0.7788
# val_f1_macro: 0.5263
# Epoch 5/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.7329 - val_loss: 0.6326
# val_f1_macro: 0.5928
# Epoch 6/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.6369 - val_loss: 0.6245
# val_f1_macro: 0.6263
# Epoch 7/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.6223 - val_loss: 0.6451
# val_f1_macro: 0.6308
# Epoch 8/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.6056 - val_loss: 0.5096
# val_f1_macro: 0.6606
# Epoch 9/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.5987 - val_loss: 0.5725
# val_f1_macro: 0.6107
# Epoch 10/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.5189 - val_loss: 0.5195
# val_f1_macro: 0.6146
# Epoch 11/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.4836 - val_loss: 0.4871
# val_f1_macro: 0.7126
# Epoch 12/200
# 4000/4000 [==============================] - 47s 12ms/sample - loss: 0.4869 - val_loss: 0.4097
# val_f1_macro: 0.7370
# Epoch 13/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.4049 - val_loss: 0.4068
# val_f1_macro: 0.7569
# Epoch 14/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.4253 - val_loss: 0.4041
# val_f1_macro: 0.7250
# Epoch 15/200
# 4000/4000 [==============================] - 47s 12ms/sample - loss: 0.4528 - val_loss: 0.4046
# val_f1_macro: 0.6884
# Epoch 16/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.4133 - val_loss: 0.3995
# val_f1_macro: 0.7232
# Epoch 17/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.3791 - val_loss: 0.5216
# val_f1_macro: 0.6996
# Epoch 18/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.3741 - val_loss: 0.2895
# val_f1_macro: 0.7959
# Epoch 19/200
# 4000/4000 [==============================] - 47s 12ms/sample - loss: 0.3126 - val_loss: 0.2927
# val_f1_macro: 0.8006
# Epoch 20/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.3558 - val_loss: 0.3548
# val_f1_macro: 0.7393
# Epoch 21/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2877 - val_loss: 0.2567
# val_f1_macro: 0.8278
# Epoch 22/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2744 - val_loss: 0.2623
# val_f1_macro: 0.8307
# Epoch 23/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.3350 - val_loss: 0.3230
# val_f1_macro: 0.7824
# Epoch 24/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.3295 - val_loss: 0.2510
# val_f1_macro: 0.8239
# Epoch 25/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2555 - val_loss: 0.2588
# val_f1_macro: 0.8367
# Epoch 26/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2826 - val_loss: 0.3913
# val_f1_macro: 0.7428
# Epoch 27/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.4088 - val_loss: 0.3459
# val_f1_macro: 0.7798
# Epoch 28/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.3049 - val_loss: 0.2779
# val_f1_macro: 0.8239
# Epoch 29/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2757 - val_loss: 0.2659
# val_f1_macro: 0.8118
# Epoch 30/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2604 - val_loss: 0.2675
# val_f1_macro: 0.8243
# Epoch 31/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2368 - val_loss: 0.2389
# val_f1_macro: 0.8432
# Epoch 32/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.3112 - val_loss: 0.3273
# val_f1_macro: 0.8013
# Epoch 33/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.3034 - val_loss: 0.2195
# val_f1_macro: 0.8423
# Epoch 34/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2349 - val_loss: 0.2258
# val_f1_macro: 0.8432
# Epoch 35/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2299 - val_loss: 0.2383
# val_f1_macro: 0.8237
# Epoch 36/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2832 - val_loss: 0.3860
# val_f1_macro: 0.7926
# Epoch 37/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2579 - val_loss: 0.2265
# val_f1_macro: 0.8523
# Epoch 38/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2561 - val_loss: 0.2810
# val_f1_macro: 0.7653
# Epoch 39/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2241 - val_loss: 0.2406
# val_f1_macro: 0.8369
# Epoch 40/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2441 - val_loss: 0.3121
# val_f1_macro: 0.8163
# Epoch 41/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2619 - val_loss: 0.2685
# val_f1_macro: 0.8045
# Epoch 42/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2226 - val_loss: 0.2350
# val_f1_macro: 0.8307
# Epoch 43/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2735 - val_loss: 0.2558
# val_f1_macro: 0.8274
# Epoch 44/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.2051 - val_loss: 0.1948
# val_f1_macro: 0.8681
# Epoch 45/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1813 - val_loss: 0.1877
# val_f1_macro: 0.8698
# Epoch 46/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1721 - val_loss: 0.1828
# val_f1_macro: 0.8755
# Epoch 47/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1656 - val_loss: 0.1784
# val_f1_macro: 0.8782
# Epoch 48/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1608 - val_loss: 0.1793
# val_f1_macro: 0.8786
# Epoch 49/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1577 - val_loss: 0.1748
# val_f1_macro: 0.8799
# Epoch 50/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1534 - val_loss: 0.1749
# val_f1_macro: 0.8813
# Epoch 51/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1494 - val_loss: 0.1732
# val_f1_macro: 0.8825
# Epoch 52/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1484 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 53/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 54/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 55/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 56/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 57/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 58/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 59/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 60/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 61/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 62/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 63/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 64/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 65/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 66/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 67/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 68/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 69/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 70/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 71/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 72/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 73/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 74/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 75/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 76/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 77/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 78/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 79/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 80/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 81/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 82/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 83/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 84/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 85/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 86/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 87/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 88/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 89/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 90/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 91/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 92/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 93/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 94/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 95/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 96/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 97/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 98/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 99/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 100/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 101/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 102/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 103/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 104/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 105/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 106/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 107/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 108/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 109/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 110/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 111/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 112/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 113/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 114/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 115/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 116/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 117/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 118/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 119/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 120/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 121/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 122/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 123/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 124/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 125/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 126/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 127/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 128/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 129/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 130/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 131/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 132/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 133/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 134/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 135/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 136/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 137/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 138/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 139/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 140/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 141/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 142/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 143/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 144/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 145/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 146/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 147/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 148/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 149/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 150/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 151/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 152/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 153/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 154/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 155/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 156/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 157/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 158/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 159/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 160/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 161/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 162/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 163/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 164/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 165/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 166/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 167/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 168/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 169/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 170/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 171/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 172/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 173/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 174/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 175/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 176/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 177/200
# 4000/4000 [==============================] - 46s 11ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 178/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 179/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 180/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 181/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 182/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 183/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 184/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 185/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 186/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 187/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 188/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 189/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 190/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 191/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 192/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 193/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 194/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 195/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 196/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 197/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 198/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 199/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731
# val_f1_macro: 0.8825
# Epoch 200/200
# 4000/4000 [==============================] - 46s 12ms/sample - loss: 0.1483 - val_loss: 0.1731

# %% [markdown]
# # Evaluate

# %%
model.load_weights('model.h5')
valid_pred = model.predict(X_valid, batch_size=64).argmax(axis=-1)
f1_score(y_valid.reshape(-1), valid_pred.reshape(-1), average='macro')
# Out:
# 0.882512961138132

# %% [markdown]
# # Submit

# %%
test_pred = model.predict(X_test, batch_size=64).argmax(axis=-1)
sub.open_channels = test_pred.reshape(-1)
sub.to_csv('submission.csv', index=False)
